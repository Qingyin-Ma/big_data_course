# %% [markdown]
# ## Pandas
#
# https://pandas.pydata.org/docs/index.html
#
# https://pandas.pydata.org/docs/user_guide/10min.html#min

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Object creation
#
# Creating a `Series` by passing a list of values, letting pandas create a default integer index:

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Creating a `DataFrame` by passing a NumPy array, with a datetime index using `date_range()` and labeled columns:

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=['A','B','C','D'])
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.157775  0.305050  0.338499  1.279784
# 2013-01-02 -0.591920  1.730402  0.282546 -1.847008
# 2013-01-03 -0.304947  0.145724 -1.531427  0.804228
# 2013-01-04 -1.747533  1.220149  0.786982 -0.316845
# 2013-01-05  1.030304  0.104551 -0.269223  0.690260
# 2013-01-06 -0.054031 -0.326016 -0.035340 -0.966094

# %%
list('ABCD')
# Out:
# ['A', 'B', 'C', 'D']

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
np.random.seed(1234)
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.471435 -1.190976  1.432707 -0.312652
# 2013-01-02 -0.720589  0.887163  0.859588 -0.636524
# 2013-01-03  0.015696 -2.242685  1.150036  0.991946
# 2013-01-04  0.953324 -2.021255 -0.334077  0.002118
# 2013-01-05  0.405453  0.289092  1.321158 -1.546906
# 2013-01-06 -0.202646 -0.655969  0.193421  0.553439

# %% [markdown]
# Creating a `DataFrame` by passing a dictionary of objects that can be converted into a series-like structure:

# %%
dic_1 = {
    'A': 1.,
    'B': pd.Timestamp('20130102'),
    'C': pd.Series(1, index=range(4), dtype='float'),
    'D': np.array([3]*4, dtype='int'),
    'E': pd.Categorical(['test', 'train', 'test', 'train']),
    'F': 'foo'
}

dic_1
# Out:
# {'A': 1.0,
#  'B': Timestamp('2013-01-02 00:00:00'),
#  'C': 0    1.0
#  1    1.0
#  2    1.0
#  3    1.0
#  dtype: float64,
#  'D': array([3, 3, 3, 3]),
#  'E': ['test', 'train', 'test', 'train']
#  Categories (2, object): ['test', 'train'],
#  'F': 'foo'}

# %%
df2 = pd.DataFrame(dic_1)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
np.array([3]*4, dtype='float32')
# Out:
# array([3., 3., 3., 3.], dtype=float32)

# %%
pd.Series(1., index=list(range(4)))
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# dtype: float64

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float64
# D            int32
# E         category
# F           object
# dtype: object

# %% [markdown]
# ### Viewing data
#
# View the top and bottom rows of the frame respectively:

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.471435 -1.190976  1.432707 -0.312652
# 2013-01-02 -0.720589  0.887163  0.859588 -0.636524
# 2013-01-03  0.015696 -2.242685  1.150036  0.991946
# 2013-01-04  0.953324 -2.021255 -0.334077  0.002118
# 2013-01-05  0.405453  0.289092  1.321158 -1.546906

# %%
df.tail()
# Out:
#                    A         B         C         D
# 2013-01-02 -0.720589  0.887163  0.859588 -0.636524
# 2013-01-03  0.015696 -2.242685  1.150036  0.991946
# 2013-01-04  0.953324 -2.021255 -0.334077  0.002118
# 2013-01-05  0.405453  0.289092  1.321158 -1.546906
# 2013-01-06 -0.202646 -0.655969  0.193421  0.553439

# %% [markdown]
# Display the `DataFrame.index` or `DataFrame.columns`:

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %% [markdown]
# The NumPy representation of the underlying data:

# %%
df.to_numpy()
# Out:
# array([[ 4.71435164e-01, -1.19097569e+00,  1.43270697e+00,
#         -3.12651896e-01],
#        [-7.20588733e-01,  8.87162940e-01,  8.59588414e-01,
#         -6.36523504e-01],
#        [ 1.56963721e-02, -2.24268495e+00,  1.15003572e+00,
#          9.91946022e-01],
#        [ 9.53324128e-01, -2.02125482e+00, -3.34077366e-01,
#          2.11836468e-03],
#        [ 4.05453412e-01,  2.89091941e-01,  1.32115819e+00,
#         -1.54690555e+00],
#        [-2.02646325e-01, -6.55969344e-01,  1.93421376e-01,
#          5.53438911e-01]])

# %%
np.array(df)
# Out:
# array([[ 4.71435164e-01, -1.19097569e+00,  1.43270697e+00,
#         -3.12651896e-01],
#        [-7.20588733e-01,  8.87162940e-01,  8.59588414e-01,
#         -6.36523504e-01],
#        [ 1.56963721e-02, -2.24268495e+00,  1.15003572e+00,
#          9.91946022e-01],
#        [ 9.53324128e-01, -2.02125482e+00, -3.34077366e-01,
#          2.11836468e-03],
#        [ 4.05453412e-01,  2.89091941e-01,  1.32115819e+00,
#         -1.54690555e+00],
#        [-2.02646325e-01, -6.55969344e-01,  1.93421376e-01,
#          5.53438911e-01]])

# %% [markdown]
# A quick statistic summary of your data:

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.153779 -0.822438  0.770472 -0.158096
# std    0.585516  1.247079  0.699548  0.898456
# min   -0.720589 -2.242685 -0.334077 -1.546906
# 25%   -0.148061 -1.813685  0.359963 -0.555556
# 50%    0.210575 -0.923473  1.004812 -0.155267
# 75%    0.454940  0.052827  1.278378  0.415609
# max    0.953324  0.887163  1.432707  0.991946

# %% [markdown]
# Transposing your data:

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.471435   -0.720589    0.015696    0.953324    0.405453   -0.202646
# B   -1.190976    0.887163   -2.242685   -2.021255    0.289092   -0.655969
# C    1.432707    0.859588    1.150036   -0.334077    1.321158    0.193421
# D   -0.312652   -0.636524    0.991946    0.002118   -1.546906    0.553439

# %% [markdown]
# Sorting by an axis:

# %%
df.sort_index(axis=0)
# Out:
#                    A         B         C         D
# 2013-01-01  0.471435 -1.190976  1.432707 -0.312652
# 2013-01-02 -0.720589  0.887163  0.859588 -0.636524
# 2013-01-03  0.015696 -2.242685  1.150036  0.991946
# 2013-01-04  0.953324 -2.021255 -0.334077  0.002118
# 2013-01-05  0.405453  0.289092  1.321158 -1.546906
# 2013-01-06 -0.202646 -0.655969  0.193421  0.553439

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.471435 -1.190976  1.432707 -0.312652
# 2013-01-02 -0.720589  0.887163  0.859588 -0.636524
# 2013-01-03  0.015696 -2.242685  1.150036  0.991946
# 2013-01-04  0.953324 -2.021255 -0.334077  0.002118
# 2013-01-05  0.405453  0.289092  1.321158 -1.546906
# 2013-01-06 -0.202646 -0.655969  0.193421  0.553439

# %% [markdown]
# ### Selection
#
# #### Getting
#
# Selecting a single column, which yields a `Series`.

# %%
df['A']
# Out:
# 2013-01-01    0.471435
# 2013-01-02   -0.720589
# 2013-01-03    0.015696
# 2013-01-04    0.953324
# 2013-01-05    0.405453
# 2013-01-06   -0.202646
# Freq: D, Name: A, dtype: float64

# %%
df.A
# Out:
# 2013-01-01    0.471435
# 2013-01-02   -0.720589
# 2013-01-03    0.015696
# 2013-01-04    0.953324
# 2013-01-05    0.405453
# 2013-01-06   -0.202646
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# Slicing the rows:

# %%
df[:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.471435 -1.190976  1.432707 -0.312652
# 2013-01-02 -0.720589  0.887163  0.859588 -0.636524
# 2013-01-03  0.015696 -2.242685  1.150036  0.991946

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02 -0.720589  0.887163  0.859588 -0.636524
# 2013-01-03  0.015696 -2.242685  1.150036  0.991946
# 2013-01-04  0.953324 -2.021255 -0.334077  0.002118

# %% [markdown]
# #### Selection by label
#
# For getting a cross section using a label:

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.loc[dates[0]]
# Out:
# A    0.471435
# B   -1.190976
# C    1.432707
# D   -0.312652
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[dates[0], ['A','B']]
# Out:
# A    0.471435
# B   -1.190976
# Name: 2013-01-01 00:00:00, dtype: float64

# %% [markdown]
# Selecting on a multi-axis by label:

# %%
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2013-01-01  0.471435 -1.190976
# 2013-01-02 -0.720589  0.887163
# 2013-01-03  0.015696 -2.242685
# 2013-01-04  0.953324 -2.021255
# 2013-01-05  0.405453  0.289092
# 2013-01-06 -0.202646 -0.655969

# %%
df.loc[1:2, ['A','B']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.loc[1:2, ['A','B']]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1339, in _LocIndexer._getitem_tuple(self, tup)
#    1336 if self._multi_take_opportunity(tup):
#    1337     return self._multi_take(tup)
# -> 1339 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:994, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
# ...

# %% [markdown]
# #### Selection by position
#
# For getting a value explicitly:

# %%
df.iloc[1,1]
# Out:
# 0.8871629403077386

# %% [markdown]
# By integer slices, acting similar to NumPy/Python:

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.720589  0.887163  0.859588 -0.636524
# 2013-01-03  0.015696 -2.242685  1.150036  0.991946

# %% [markdown]
# For slicing columns explicitly:

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01 -1.190976  1.432707
# 2013-01-02  0.887163  0.859588
# 2013-01-03 -2.242685  1.150036
# 2013-01-04 -2.021255 -0.334077
# 2013-01-05  0.289092  1.321158
# 2013-01-06 -0.655969  0.193421

# %% [markdown]
# By lists of integer position locations, similar to the NumPy/Python style:

# %%
df.iloc[[1,2,4], [0,2]]
# Out:
#                    A         C
# 2013-01-02 -0.720589  0.859588
# 2013-01-03  0.015696  1.150036
# 2013-01-05  0.405453  1.321158

# %% [markdown]
# #### Boolean indexing
#
# Using a single column’s values to select data:

# %%
df[df['A']>0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.471435 -1.190976  1.432707 -0.312652
# 2013-01-03  0.015696 -2.242685  1.150036  0.991946
# 2013-01-04  0.953324 -2.021255 -0.334077  0.002118
# 2013-01-05  0.405453  0.289092  1.321158 -1.546906

# %% [markdown]
# Selecting values from a DataFrame where a boolean condition is met:

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.471435       NaN  1.432707       NaN
# 2013-01-02       NaN  0.887163  0.859588       NaN
# 2013-01-03  0.015696       NaN  1.150036  0.991946
# 2013-01-04  0.953324       NaN       NaN  0.002118
# 2013-01-05  0.405453  0.289092  1.321158       NaN
# 2013-01-06       NaN       NaN  0.193421  0.553439

# %% [markdown]
# Using the `isin()` method for filtering:

# %%
df2 = df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.471435 -1.190976  1.432707 -0.312652    one
# 2013-01-02 -0.720589  0.887163  0.859588 -0.636524    one
# 2013-01-03  0.015696 -2.242685  1.150036  0.991946    two
# 2013-01-04  0.953324 -2.021255 -0.334077  0.002118  three
# 2013-01-05  0.405453  0.289092  1.321158 -1.546906   four
# 2013-01-06 -0.202646 -0.655969  0.193421  0.553439  three

# %%
df2[df2['E'].isin((['two', 'four']))]
# Out:
#                    A         B         C         D     E
# 2013-01-03  0.015696 -2.242685  1.150036  0.991946   two
# 2013-01-05  0.405453  0.289092  1.321158 -1.546906  four

# %% [markdown]
# #### Setting
#
# Setting a new column automatically aligns the data by the indexes:

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102', periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.471435 -1.190976  1.432707 -0.312652  NaN
# 2013-01-02 -0.720589  0.887163  0.859588 -0.636524  1.0
# 2013-01-03  0.015696 -2.242685  1.150036  0.991946  2.0
# 2013-01-04  0.953324 -2.021255 -0.334077  0.002118  3.0
# 2013-01-05  0.405453  0.289092  1.321158 -1.546906  4.0
# 2013-01-06 -0.202646 -0.655969  0.193421  0.553439  5.0

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# Setting values by label:

# %%
df.loc[dates[0], 'A'] = 0
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000 -1.190976  1.432707 -0.312652  NaN
# 2013-01-02 -0.720589  0.887163  0.859588 -0.636524  1.0
# 2013-01-03  0.015696 -2.242685  1.150036  0.991946  2.0
# 2013-01-04  0.953324 -2.021255 -0.334077  0.002118  3.0
# 2013-01-05  0.405453  0.289092  1.321158 -1.546906  4.0
# 2013-01-06 -0.202646 -0.655969  0.193421  0.553439  5.0

# %% [markdown]
# Setting values by position:

# %%
df.iloc[0,1] = 1
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  1.000000  1.432707 -0.312652  NaN
# 2013-01-02 -0.720589  0.887163  0.859588 -0.636524  1.0
# 2013-01-03  0.015696 -2.242685  1.150036  0.991946  2.0
# 2013-01-04  0.953324 -2.021255 -0.334077  0.002118  3.0
# 2013-01-05  0.405453  0.289092  1.321158 -1.546906  4.0
# 2013-01-06 -0.202646 -0.655969  0.193421  0.553439  5.0

# %% [markdown]
# Setting by assigning with a NumPy array:

# %%
df.loc[:, 'D'] = 5
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  1.000000  1.432707  5.0  NaN
# 2013-01-02 -0.720589  0.887163  0.859588  5.0  1.0
# 2013-01-03  0.015696 -2.242685  1.150036  5.0  2.0
# 2013-01-04  0.953324 -2.021255 -0.334077  5.0  3.0
# 2013-01-05  0.405453  0.289092  1.321158  5.0  4.0
# 2013-01-06 -0.202646 -0.655969  0.193421  5.0  5.0

# %% [markdown]
# A `where` operation with setting:

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000 -1.000000 -1.432707 -5.0  NaN
# 2013-01-02 -0.720589 -0.887163 -0.859588 -5.0 -1.0
# 2013-01-03 -0.015696 -2.242685 -1.150036 -5.0 -2.0
# 2013-01-04 -0.953324 -2.021255 -0.334077 -5.0 -3.0
# 2013-01-05 -0.405453 -0.289092 -1.321158 -5.0 -4.0
# 2013-01-06 -0.202646 -0.655969 -0.193421 -5.0 -5.0

# %% [markdown]
# ### Missing data

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'F'], dtype='object')

# %%
df.columns + ['E']
# Out:
# Index(['AE', 'BE', 'CE', 'DE', 'FE'], dtype='object')

# %%
list(df.columns) + ['E']
# Out:
# ['A', 'B', 'C', 'D', 'F', 'E']

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  1.000000  1.432707  5.0  NaN
# 2013-01-02 -0.720589  0.887163  0.859588  5.0  1.0
# 2013-01-03  0.015696 -2.242685  1.150036  5.0  2.0
# 2013-01-04  0.953324 -2.021255 -0.334077  5.0  3.0
# 2013-01-05  0.405453  0.289092  1.321158  5.0  4.0
# 2013-01-06 -0.202646 -0.655969  0.193421  5.0  5.0

# %% [markdown]
# Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data:

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns)+['E'])
df1
# Out:
#                    A         B         C    D    F   E
# 2013-01-01  0.000000  1.000000  1.432707  5.0  NaN NaN
# 2013-01-02 -0.720589  0.887163  0.859588  5.0  1.0 NaN
# 2013-01-03  0.015696 -2.242685  1.150036  5.0  2.0 NaN
# 2013-01-04  0.953324 -2.021255 -0.334077  5.0  3.0 NaN

# %%
df1.loc[dates[0]:dates[1], 'E'] = 1
df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  1.000000  1.432707  5.0  NaN  1.0
# 2013-01-02 -0.720589  0.887163  0.859588  5.0  1.0  1.0
# 2013-01-03  0.015696 -2.242685  1.150036  5.0  2.0  NaN
# 2013-01-04  0.953324 -2.021255 -0.334077  5.0  3.0  NaN

# %% [markdown]
# Drop any rows that have missing data:

# %%
df1.dropna()
# Out:
#                    A         B         C    D    F    E
# 2013-01-02 -0.720589  0.887163  0.859588  5.0  1.0  1.0

# %% [markdown]
# Fill the missing data:

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  1.000000  1.432707  5.0  5.0  1.0
# 2013-01-02 -0.720589  0.887163  0.859588  5.0  1.0  1.0
# 2013-01-03  0.015696 -2.242685  1.150036  5.0  2.0  5.0
# 2013-01-04  0.953324 -2.021255 -0.334077  5.0  3.0  5.0

# %%
df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  1.000000  1.432707  5.0  NaN  1.0
# 2013-01-02 -0.720589  0.887163  0.859588  5.0  1.0  1.0
# 2013-01-03  0.015696 -2.242685  1.150036  5.0  2.0  NaN
# 2013-01-04  0.953324 -2.021255 -0.334077  5.0  3.0  NaN

# %% [markdown]
# Gets the boolean mask where values are `nan`:

# %%
df1.isna()
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# ### Operations
#
# Performing a descriptive statistic:

# %%
df.mean()
# Out:
# A    0.075206
# B   -0.457276
# C    0.770472
# D    5.000000
# F    3.000000
# dtype: float64

# %% [markdown]
# Same operation on the other axis:

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    1.858177
# 2013-01-02    1.405233
# 2013-01-03    1.184609
# 2013-01-04    1.319598
# 2013-01-05    2.203141
# 2013-01-06    1.866961
# Freq: D, dtype: float64

# %% [markdown]
# Operating with objects that have different dimensionality and need alignment. In addition, pandas automatically broadcasts along the specified dimension:

# %%
s = pd.Series([1,3,5, np.nan, 6,8], index=dates)
s
# Out:
# 2013-01-01    1.0
# 2013-01-02    3.0
# 2013-01-03    5.0
# 2013-01-04    NaN
# 2013-01-05    6.0
# 2013-01-06    8.0
# Freq: D, dtype: float64

# %%
s = s.shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %% [markdown]
# ### Apply
#
# Apply a user defined function to the data:

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C     D     F
# 2013-01-01  0.000000  1.000000  1.432707   5.0   NaN
# 2013-01-02 -0.720589  1.887163  2.292295  10.0   1.0
# 2013-01-03 -0.704892 -0.355522  3.442331  15.0   3.0
# 2013-01-04  0.248432 -2.376777  3.108254  20.0   6.0
# 2013-01-05  0.653885 -2.087685  4.429412  25.0  10.0
# 2013-01-06  0.451239 -2.743654  4.622833  30.0  15.0

# %% [markdown]
# ### Histogramming

# %%
s = pd.Series(np.random.randint(0,7, size=10))
s
# Out:
# 0    3
# 1    3
# 2    2
# 3    1
# 4    6
# 5    3
# 6    4
# 7    2
# 8    3
# 9    6
# dtype: int32

# %%
s.value_counts()
# Out:
# 3    4
# 2    2
# 6    2
# 1    1
# 4    1
# Name: count, dtype: int64

# %% [markdown]
# ### Merge

# %%
df = pd.DataFrame(np.random.randn(10,4))
df
# Out:
#           0         1         2         3
# 0 -1.781148  2.290227 -1.505685 -1.080808
# 1  0.513695  1.098981  0.460085  0.202690
# 2 -1.489094 -0.646127  1.501537 -0.396477
# 3 -0.751195  0.178778 -0.836739  0.509396
# 4 -0.041124 -0.111910 -0.759007 -0.045936
# 5 -0.907728 -0.279114  0.244120  0.366056
# 6 -0.271001 -0.071207  0.084837  0.120414
# 7 -1.268647  0.524837  0.983838 -1.264908
# 8  0.332566  0.750438 -1.079212 -0.628115
# 9  0.299347  0.127277  0.926190  2.455240

# %%
df[:3]
# Out:
#           0         1         2         3
# 0 -1.781148  2.290227 -1.505685 -1.080808
# 1  0.513695  1.098981  0.460085  0.202690
# 2 -1.489094 -0.646127  1.501537 -0.396477

# %%
df[3:7]
# Out:
#           0         1         2         3
# 3 -0.751195  0.178778 -0.836739  0.509396
# 4 -0.041124 -0.111910 -0.759007 -0.045936
# 5 -0.907728 -0.279114  0.244120  0.366056
# 6 -0.271001 -0.071207  0.084837  0.120414

# %%
df[7:]
# Out:
#           0         1         2         3
# 7 -1.268647  0.524837  0.983838 -1.264908
# 8  0.332566  0.750438 -1.079212 -0.628115
# 9  0.299347  0.127277  0.926190  2.455240

# %%
pieces = [df[:3], df[3:7], df[7:]]
pieces
# Out:
# [          0         1         2         3
#  0 -1.781148  2.290227 -1.505685 -1.080808
#  1  0.513695  1.098981  0.460085  0.202690
#  2 -1.489094 -0.646127  1.501537 -0.396477,
#            0         1         2         3
#  3 -0.751195  0.178778 -0.836739  0.509396
#  4 -0.041124 -0.111910 -0.759007 -0.045936
#  5 -0.907728 -0.279114  0.244120  0.366056
#  6 -0.271001 -0.071207  0.084837  0.120414,
#            0         1         2         3
#  7 -1.268647  0.524837  0.983838 -1.264908
#  8  0.332566  0.750438 -1.079212 -0.628115
#  9  0.299347  0.127277  0.926190  2.455240]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -1.781148  2.290227 -1.505685 -1.080808
# 1  0.513695  1.098981  0.460085  0.202690
# 2 -1.489094 -0.646127  1.501537 -0.396477
# 3 -0.751195  0.178778 -0.836739  0.509396
# 4 -0.041124 -0.111910 -0.759007 -0.045936
# 5 -0.907728 -0.279114  0.244120  0.366056
# 6 -0.271001 -0.071207  0.084837  0.120414
# 7 -1.268647  0.524837  0.983838 -1.264908
# 8  0.332566  0.750438 -1.079212 -0.628115
# 9  0.299347  0.127277  0.926190  2.455240

# %% [markdown]
# ### Time Series
#
# Pandas has simple, powerful, and efficient functionality for performing resampling operations during frequency conversion (e.g., converting secondly data into 5-minutely data).
#
# Converting secondly data into 5-minutely data by summation:

# %%
rng = pd.date_range('1/1/2012', periods=5000, freq='S')
rng
# Out:
# DatetimeIndex(['2012-01-01 00:00:00', '2012-01-01 00:00:01',
#                '2012-01-01 00:00:02', '2012-01-01 00:00:03',
#                '2012-01-01 00:00:04', '2012-01-01 00:00:05',
#                '2012-01-01 00:00:06', '2012-01-01 00:00:07',
#                '2012-01-01 00:00:08', '2012-01-01 00:00:09',
#                ...
#                '2012-01-01 01:23:10', '2012-01-01 01:23:11',
#                '2012-01-01 01:23:12', '2012-01-01 01:23:13',
#                '2012-01-01 01:23:14', '2012-01-01 01:23:15',
#                '2012-01-01 01:23:16', '2012-01-01 01:23:17',
#                '2012-01-01 01:23:18', '2012-01-01 01:23:19'],
#               dtype='datetime64[ns]', length=5000, freq='S')

# %%
ts = pd.Series(np.random.randint(0,500, len(rng)), index=rng)
ts
# Out:
# 2012-01-01 00:00:00    150
# 2012-01-01 00:00:01    440
# 2012-01-01 00:00:02    468
# 2012-01-01 00:00:03    136
# 2012-01-01 00:00:04    172
#                       ...
# 2012-01-01 01:23:15    262
# 2012-01-01 01:23:16    303
# 2012-01-01 01:23:17    340
# 2012-01-01 01:23:18    256
# 2012-01-01 01:23:19    303
# Freq: S, Length: 5000, dtype: int32

# %%
ts.resample('5Min').sum()
# Out:
# 2012-01-01 00:00:00    76653
# 2012-01-01 00:05:00    70161
# 2012-01-01 00:10:00    71892
# 2012-01-01 00:15:00    74456
# 2012-01-01 00:20:00    75833
# 2012-01-01 00:25:00    72763
# 2012-01-01 00:30:00    71585
# 2012-01-01 00:35:00    76566
# 2012-01-01 00:40:00    75023
# 2012-01-01 00:45:00    77600
# 2012-01-01 00:50:00    72258
# 2012-01-01 00:55:00    76969
# 2012-01-01 01:00:00    73327
# 2012-01-01 01:05:00    70668
# 2012-01-01 01:10:00    75329
# 2012-01-01 01:15:00    73364
# 2012-01-01 01:20:00    50519
# Freq: 5T, dtype: int32

# %% [markdown]
# Converting monthly data into annual data by averaging:

# %%
rng = pd.date_range('20000101', periods=100, freq='MS')
rng
# Out:
# DatetimeIndex(['2000-01-01', '2000-02-01', '2000-03-01', '2000-04-01',
#                '2000-05-01', '2000-06-01', '2000-07-01', '2000-08-01',
#                '2000-09-01', '2000-10-01', '2000-11-01', '2000-12-01',
#                '2001-01-01', '2001-02-01', '2001-03-01', '2001-04-01',
#                '2001-05-01', '2001-06-01', '2001-07-01', '2001-08-01',
#                '2001-09-01', '2001-10-01', '2001-11-01', '2001-12-01',
#                '2002-01-01', '2002-02-01', '2002-03-01', '2002-04-01',
#                '2002-05-01', '2002-06-01', '2002-07-01', '2002-08-01',
#                '2002-09-01', '2002-10-01', '2002-11-01', '2002-12-01',
#                '2003-01-01', '2003-02-01', '2003-03-01', '2003-04-01',
#                '2003-05-01', '2003-06-01', '2003-07-01', '2003-08-01',
#                '2003-09-01', '2003-10-01', '2003-11-01', '2003-12-01',
#                '2004-01-01', '2004-02-01', '2004-03-01', '2004-04-01',
# ...

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2000-01-01    1.031141
# 2000-02-01    0.529412
# 2000-03-01   -0.933707
# 2000-04-01   -1.025651
# 2000-05-01    1.581512
#                 ...
# 2007-12-01    2.990877
# 2008-01-01   -1.734529
# 2008-02-01    1.518227
# 2008-03-01   -0.706861
# 2008-04-01    0.174108
# Freq: MS, Length: 100, dtype: float64

# %%
ts2 = ts.resample('Y').mean()
ts2
# Out:
# 2000-12-31   -0.206850
# 2001-12-31    0.306418
# 2002-12-31    0.288540
# 2003-12-31    0.237596
# 2004-12-31   -0.173003
# 2005-12-31   -0.341516
# 2006-12-31    0.301834
# 2007-12-31    0.380726
# 2008-12-31   -0.187264
# Freq: A-DEC, dtype: float64

# %%
ts2 = ts2.to_period('M')
ts2
# Out:
# 2000-12   -0.206850
# 2001-12    0.306418
# 2002-12    0.288540
# 2003-12    0.237596
# 2004-12   -0.173003
# 2005-12   -0.341516
# 2006-12    0.301834
# 2007-12    0.380726
# 2008-12   -0.187264
# Freq: M, dtype: float64
